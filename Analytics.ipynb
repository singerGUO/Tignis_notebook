# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import glob
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#gathering csv data using glob
all_csv_files = glob.glob("/dbfs/FileStore/tables/2019/*.csv")
print("--" + str(all_csv_files))
loops=len(all_csv_files)
all_csv_files
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">--[&#39;/dbfs/FileStore/tables/2019/RTU_1_BldgStatPress_2019-343cc.csv&#39;, &#39;/dbfs/FileStore/tables/2019/RTU_1_ClgCapacity_2019-441eb.csv&#39;, &#39;/dbfs/FileStore/tables/2019/RTU_1_ControlTemp_2019-5ab53.csv&#39;, &#39;/dbfs/FileStore/tables/2019/RTU_1_DAClgSetpt_2019-c035a.csv&#39;, &#39;/dbfs/FileStore/tables/2019/RTU_1_DischAirTemp_2019-80828.csv&#39;, &#39;/dbfs/FileStore/tables/2019/RTU_1_DuctStatPress_2019-178e3.csv&#39;, &#39;/dbfs/FileStore/tables/2019/RTU_1_DuctStaticSP_2019-c3d5a.csv&#39;, &#39;/dbfs/FileStore/tables/2019/RTU_1_EconCapacity_2019-ee6fe.csv&#39;, &#39;/dbfs/FileStore/tables/2019/RTU_1_EffDATempSP_2019-81083.csv&#39;, &#39;/dbfs/FileStore/tables/2019/RTU_1_ExhFanValue_2019-997c1.csv&#39;, &#39;/dbfs/FileStore/tables/2019/RTU_1_FanSpd_2019-c8b72.csv&#39;, &#39;/dbfs/FileStore/tables/2019/RTU_1_OutdoorTemp_2019-db487.csv&#39;, &#39;/dbfs/FileStore/tables/2019/RTU_1_RATemp_2019-b6e4a.csv&#39;]
# Out[18]: [&#39;/dbfs/FileStore/tables/2019/RTU_1_BldgStatPress_2019-343cc.csv&#39;,
#  &#39;/dbfs/FileStore/tables/2019/RTU_1_ClgCapacity_2019-441eb.csv&#39;,
#  &#39;/dbfs/FileStore/tables/2019/RTU_1_ControlTemp_2019-5ab53.csv&#39;,
#  &#39;/dbfs/FileStore/tables/2019/RTU_1_DAClgSetpt_2019-c035a.csv&#39;,
#  &#39;/dbfs/FileStore/tables/2019/RTU_1_DischAirTemp_2019-80828.csv&#39;,
#  &#39;/dbfs/FileStore/tables/2019/RTU_1_DuctStatPress_2019-178e3.csv&#39;,
#  &#39;/dbfs/FileStore/tables/2019/RTU_1_DuctStaticSP_2019-c3d5a.csv&#39;,
#  &#39;/dbfs/FileStore/tables/2019/RTU_1_EconCapacity_2019-ee6fe.csv&#39;,
#  &#39;/dbfs/FileStore/tables/2019/RTU_1_EffDATempSP_2019-81083.csv&#39;,
#  &#39;/dbfs/FileStore/tables/2019/RTU_1_ExhFanValue_2019-997c1.csv&#39;,
#  &#39;/dbfs/FileStore/tables/2019/RTU_1_FanSpd_2019-c8b72.csv&#39;,
#  &#39;/dbfs/FileStore/tables/2019/RTU_1_OutdoorTemp_2019-db487.csv&#39;,
#  &#39;/dbfs/FileStore/tables/2019/RTU_1_RATemp_2019-b6e4a.csv&#39;]</div>

# %%
#data import to notebook
#doesn't seem to be needed
# https://docs.databricks.com/data/data.html
from os import walk

mypath = "/dbfs/FileStore/tables"
f = []
for (dirpath, dirnames, filenames) in walk(mypath):
    f.extend(filenames)
    break
print(f)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;Analytics.ipynb&#39;, &#39;RTU_1_BldgStatPress_2019-343cc.csv&#39;, &#39;RTU_1_BldgStatPress_2020_present-f4ff4.csv&#39;, &#39;RTU_1_ClgCapacity_2019-441eb.csv&#39;, &#39;RTU_1_ClgCapacity_2020_present-4fea9.csv&#39;, &#39;RTU_1_ControlTemp_2019-5ab53.csv&#39;, &#39;RTU_1_ControlTemp_2020_present-4d009.csv&#39;, &#39;RTU_1_DAClgSetpt_2019-c035a.csv&#39;, &#39;RTU_1_DAClgSetpt_2020_present-ab80f.csv&#39;, &#39;RTU_1_DischAirTemp_2019-80828.csv&#39;, &#39;RTU_1_DischAirTemp_2020_present-a801f.csv&#39;, &#39;RTU_1_DuctStatPress_2019-178e3.csv&#39;, &#39;RTU_1_DuctStatPress_2020_present-78d21.csv&#39;, &#39;RTU_1_DuctStaticSP_2019-c3d5a.csv&#39;, &#39;RTU_1_DuctStaticSP_2020_present-48688.csv&#39;, &#39;RTU_1_EconCapacity_2019-ee6fe.csv&#39;, &#39;RTU_1_EconCapacity_2020_present-215d5.csv&#39;, &#39;RTU_1_EffDATempSP_2019-81083.csv&#39;, &#39;RTU_1_EffDATempSP_2020_present-bef8f.csv&#39;, &#39;RTU_1_ExhFanValue_2019-997c1.csv&#39;, &#39;RTU_1_ExhFanValue_2020_present-a54b1.csv&#39;, &#39;RTU_1_FanSpd_2019-c8b72.csv&#39;, &#39;RTU_1_FanSpd_2020_present-714cd.csv&#39;, &#39;RTU_1_OutdoorTemp_2019-db487.csv&#39;, &#39;RTU_1_OutdoorTemp_2020_present-7dd77.csv&#39;, &#39;RTU_1_RATemp_2019-b6e4a.csv&#39;, &#39;RTU_1_RATemp_2020_present-5c0e9.csv&#39;]
# </div>

# %%
pd.read_csv("/dbfs/FileStore/tables/RTU_1_BldgStatPress_2019-343cc.csv")
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Timestamp</th>
#       <th>RTU_1 BldgStatPress(in/wc)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>01-Jan-19 12:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>01-Jan-19 04:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>01-Jan-19 08:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>01-Jan-19 12:00:00 pm</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>01-Jan-19 04:00:00 pm</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>01-Jan-19 08:00:00 pm</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>02-Jan-19 12:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>02-Jan-19 04:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>02-Jan-19 08:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>02-Jan-19 12:00:00 pm</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>02-Jan-19 04:00:00 pm</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>02-Jan-19 08:00:00 pm</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>03-Jan-19 12:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>03-Jan-19 04:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>03-Jan-19 08:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>03-Jan-19 12:00:00 pm</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>03-Jan-19 04:00:00 pm</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>03-Jan-19 08:00:00 pm</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>04-Jan-19 12:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>04-Jan-19 04:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>04-Jan-19 08:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>04-Jan-19 12:00:00 pm</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>04-Jan-19 04:00:00 pm</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>04-Jan-19 08:00:00 pm</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>05-Jan-19 12:00:00 am</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>05-Jan-19 04:00:00 am</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>05-Jan-19 08:00:00 am</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>05-Jan-19 12:00:00 pm</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>05-Jan-19 04:00:00 pm</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>05-Jan-19 08:00:00 pm</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2160</th>
#       <td>27-Dec-19 12:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2161</th>
#       <td>27-Dec-19 04:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2162</th>
#       <td>27-Dec-19 08:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2163</th>
#       <td>27-Dec-19 12:00:00 pm</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2164</th>
#       <td>27-Dec-19 04:00:00 pm</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2165</th>
#       <td>27-Dec-19 08:00:00 pm</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>2166</th>
#       <td>28-Dec-19 12:00:00 am</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>2167</th>
#       <td>28-Dec-19 04:00:00 am</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>2168</th>
#       <td>28-Dec-19 08:00:00 am</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>2169</th>
#       <td>28-Dec-19 12:00:00 pm</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>2170</th>
#       <td>28-Dec-19 04:00:00 pm</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>2171</th>
#       <td>28-Dec-19 08:00:00 pm</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2172</th>
#       <td>29-Dec-19 12:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2173</th>
#       <td>29-Dec-19 04:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2174</th>
#       <td>29-Dec-19 08:00:00 am</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>2175</th>
#       <td>29-Dec-19 12:00:00 pm</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>2176</th>
#       <td>29-Dec-19 04:00:00 pm</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>2177</th>
#       <td>29-Dec-19 08:00:00 pm</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>2178</th>
#       <td>30-Dec-19 12:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2179</th>
#       <td>30-Dec-19 04:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2180</th>
#       <td>30-Dec-19 08:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2181</th>
#       <td>30-Dec-19 12:00:00 pm</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2182</th>
#       <td>30-Dec-19 04:00:00 pm</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2183</th>
#       <td>30-Dec-19 08:00:00 pm</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>2184</th>
#       <td>31-Dec-19 12:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2185</th>
#       <td>31-Dec-19 04:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2186</th>
#       <td>31-Dec-19 08:00:00 am</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2187</th>
#       <td>31-Dec-19 12:00:00 pm</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>2188</th>
#       <td>31-Dec-19 04:00:00 pm</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>2189</th>
#       <td>31-Dec-19 08:00:00 pm</td>
#       <td>0.01</td>
#     </tr>
#   </tbody>
# </table>
# <p>2190 rows × 2 columns</p>
# </div>

# %%
import numpy as np
varlist=[]

for i in range(int(loops)):
    globals() ['df'+str(i)] = pd.read_csv(all_csv_files[i])
    globals() ['df'+str(i)].set_index('Timestamp', inplace=True)
    if i == 0:
      result = df0
    else:
      result = result.merge(globals() ['df'+str(i)], on='Timestamp',how='left')
      
result
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>RTU_1 BldgStatPress(in/wc)</th>
#       <th>RTU_1 ClgCapacity(%)</th>
#       <th>RTU_1 ControlTemp(°F)</th>
#       <th>RTU_1 DAClgSetpt(°F)</th>
#       <th>RTU_1 DischAirTemp(°F)</th>
#       <th>RTU_1 DuctStatPress(in/wc)</th>
#       <th>RTU_1 DuctStaticSP(in/wc)</th>
#       <th>RTU_1 EconCapacity(%)</th>
#       <th>RTU_1 EffDATempSP(°F)</th>
#       <th>RTU_1 ExhFanValue(%)</th>
#       <th>RTU_1 FanSpd(%)</th>
#       <th>RTU_1 OutdoorTemp(°F)</th>
#       <th>RTU_1 RATemp(°F)</th>
#     </tr>
#     <tr>
#       <th>Timestamp</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01-Jan-19 12:00:00 am</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>58.1</td>
#       <td>NaN</td>
#       <td>52.4</td>
#       <td>0.13</td>
#       <td>1.80</td>
#       <td>0</td>
#       <td>65.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>36.0</td>
#       <td>58.1</td>
#     </tr>
#     <tr>
#       <th>01-Jan-19 04:00:00 am</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>64.4</td>
#       <td>NaN</td>
#       <td>60.5</td>
#       <td>0.86</td>
#       <td>1.80</td>
#       <td>15</td>
#       <td>65.0</td>
#       <td>14</td>
#       <td>24</td>
#       <td>37.1</td>
#       <td>64.4</td>
#     </tr>
#     <tr>
#       <th>01-Jan-19 08:00:00 am</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>66.4</td>
#       <td>NaN</td>
#       <td>56.6</td>
#       <td>1.80</td>
#       <td>1.80</td>
#       <td>76</td>
#       <td>55.8</td>
#       <td>33</td>
#       <td>56</td>
#       <td>39.1</td>
#       <td>66.4</td>
#     </tr>
#     <tr>
#       <th>01-Jan-19 12:00:00 pm</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>66.4</td>
#       <td>NaN</td>
#       <td>55.1</td>
#       <td>1.79</td>
#       <td>1.80</td>
#       <td>80</td>
#       <td>55.4</td>
#       <td>33</td>
#       <td>56</td>
#       <td>43.7</td>
#       <td>66.5</td>
#     </tr>
#     <tr>
#       <th>01-Jan-19 04:00:00 pm</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>64.9</td>
#       <td>NaN</td>
#       <td>54.8</td>
#       <td>1.09</td>
#       <td>1.75</td>
#       <td>42</td>
#       <td>58.6</td>
#       <td>19</td>
#       <td>31</td>
#       <td>39.9</td>
#       <td>64.9</td>
#     </tr>
#     <tr>
#       <th>01-Jan-19 08:00:00 pm</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>60.9</td>
#       <td>NaN</td>
#       <td>53.7</td>
#       <td>0.14</td>
#       <td>1.80</td>
#       <td>0</td>
#       <td>65.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>36.5</td>
#       <td>60.9</td>
#     </tr>
#     <tr>
#       <th>02-Jan-19 12:00:00 am</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>60.8</td>
#       <td>NaN</td>
#       <td>55.8</td>
#       <td>0.26</td>
#       <td>1.65</td>
#       <td>3</td>
#       <td>65.0</td>
#       <td>4</td>
#       <td>5</td>
#       <td>38.5</td>
#       <td>60.8</td>
#     </tr>
#     <tr>
#       <th>02-Jan-19 04:00:00 am</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>64.6</td>
#       <td>NaN</td>
#       <td>60.4</td>
#       <td>0.86</td>
#       <td>1.80</td>
#       <td>15</td>
#       <td>64.4</td>
#       <td>14</td>
#       <td>25</td>
#       <td>37.4</td>
#       <td>64.6</td>
#     </tr>
#     <tr>
#       <th>02-Jan-19 08:00:00 am</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>67.6</td>
#       <td>NaN</td>
#       <td>62.6</td>
#       <td>1.80</td>
#       <td>1.80</td>
#       <td>42</td>
#       <td>63.2</td>
#       <td>33</td>
#       <td>57</td>
#       <td>40.5</td>
#       <td>67.6</td>
#     </tr>
#     <tr>
#       <th>02-Jan-19 12:00:00 pm</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>69.1</td>
#       <td>NaN</td>
#       <td>65.4</td>
#       <td>1.80</td>
#       <td>1.80</td>
#       <td>28</td>
#       <td>65.0</td>
#       <td>33</td>
#       <td>58</td>
#       <td>44.9</td>
#       <td>69.1</td>
#     </tr>
#     <tr>
#       <th>02-Jan-19 04:00:00 pm</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>67.3</td>
#       <td>NaN</td>
#       <td>65.0</td>
#       <td>1.07</td>
#       <td>1.45</td>
#       <td>27</td>
#       <td>65.0</td>
#       <td>19</td>
#       <td>32</td>
#       <td>47.9</td>
#       <td>67.3</td>
#     </tr>
#     <tr>
#       <th>02-Jan-19 08:00:00 pm</th>
#       <td>0.00</td>
#       <td>0</td>
#       <td>63.4</td>
#       <td>NaN</td>
#       <td>62.7</td>
#       <td>0.23</td>
#       <td>1.20</td>
#       <td>3</td>
#       <td>65.0</td>
#       <td>4</td>
#       <td>5</td>
#       <td>50.8</td>
#       <td>63.4</td>
#     </tr>
#     <tr>
#       <th>03-Jan-19 12:00:00 am</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>61.6</td>
#       <td>NaN</td>
#       <td>60.3</td>
#       <td>0.11</td>
#       <td>1.80</td>
#       <td>0</td>
#       <td>65.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>45.6</td>
#       <td>61.6</td>
#     </tr>
#     <tr>
#       <th>03-Jan-19 04:00:00 am</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>66.0</td>
#       <td>NaN</td>
#       <td>62.8</td>
#       <td>0.66</td>
#       <td>1.80</td>
#       <td>17</td>
#       <td>64.6</td>
#       <td>14</td>
#       <td>22</td>
#       <td>46.0</td>
#       <td>66.0</td>
#     </tr>
#     <tr>
#       <th>03-Jan-19 08:00:00 am</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>69.5</td>
#       <td>NaN</td>
#       <td>64.9</td>
#       <td>1.79</td>
#       <td>1.80</td>
#       <td>67</td>
#       <td>64.9</td>
#       <td>33</td>
#       <td>57</td>
#       <td>50.5</td>
#       <td>69.5</td>
#     </tr>
#     <tr>
#       <th>03-Jan-19 12:00:00 pm</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>70.6</td>
#       <td>NaN</td>
#       <td>65.2</td>
#       <td>1.79</td>
#       <td>1.80</td>
#       <td>67</td>
#       <td>65.0</td>
#       <td>33</td>
#       <td>58</td>
#       <td>52.5</td>
#       <td>70.6</td>
#     </tr>
#     <tr>
#       <th>03-Jan-19 04:00:00 pm</th>
#       <td>0.00</td>
#       <td>0</td>
#       <td>68.2</td>
#       <td>NaN</td>
#       <td>61.4</td>
#       <td>1.07</td>
#       <td>1.45</td>
#       <td>42</td>
#       <td>62.8</td>
#       <td>19</td>
#       <td>32</td>
#       <td>52.4</td>
#       <td>68.1</td>
#     </tr>
#     <tr>
#       <th>03-Jan-19 08:00:00 pm</th>
#       <td>0.00</td>
#       <td>0</td>
#       <td>64.7</td>
#       <td>NaN</td>
#       <td>59.2</td>
#       <td>0.24</td>
#       <td>1.00</td>
#       <td>3</td>
#       <td>65.0</td>
#       <td>4</td>
#       <td>5</td>
#       <td>55.1</td>
#       <td>64.7</td>
#     </tr>
#     <tr>
#       <th>04-Jan-19 12:00:00 am</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>63.1</td>
#       <td>NaN</td>
#       <td>58.1</td>
#       <td>0.12</td>
#       <td>1.00</td>
#       <td>0</td>
#       <td>65.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>49.7</td>
#       <td>63.1</td>
#     </tr>
#     <tr>
#       <th>04-Jan-19 04:00:00 am</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>67.0</td>
#       <td>NaN</td>
#       <td>62.8</td>
#       <td>0.84</td>
#       <td>1.75</td>
#       <td>28</td>
#       <td>64.9</td>
#       <td>14</td>
#       <td>25</td>
#       <td>49.8</td>
#       <td>67.0</td>
#     </tr>
#     <tr>
#       <th>04-Jan-19 08:00:00 am</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>69.8</td>
#       <td>NaN</td>
#       <td>64.9</td>
#       <td>1.79</td>
#       <td>1.80</td>
#       <td>63</td>
#       <td>64.9</td>
#       <td>33</td>
#       <td>57</td>
#       <td>51.4</td>
#       <td>69.8</td>
#     </tr>
#     <tr>
#       <th>04-Jan-19 12:00:00 pm</th>
#       <td>0.02</td>
#       <td>0</td>
#       <td>70.3</td>
#       <td>NaN</td>
#       <td>63.5</td>
#       <td>1.80</td>
#       <td>1.80</td>
#       <td>69</td>
#       <td>63.7</td>
#       <td>33</td>
#       <td>58</td>
#       <td>52.5</td>
#       <td>70.3</td>
#     </tr>
#     <tr>
#       <th>04-Jan-19 04:00:00 pm</th>
#       <td>0.01</td>
#       <td>0</td>
#       <td>68.4</td>
#       <td>NaN</td>
#       <td>64.0</td>
#       <td>1.06</td>
#       <td>1.45</td>
#       <t

# %%
import pandas as pd
import numpy as np
 

# generating some test data
timestamp = [1440540000, 1450540000]
df1 = pd.DataFrame(
    {'timestamp': timestamp, 'a': ['val_a', 'val2_a'], 'b': ['val_b', 'val2_b'], 'c': ['val_c', 'val2_c']})
print(df1)
 

# building a different index
timestamp = timestamp * np.random.randn(abs(1))
df2 = pd.DataFrame(
    {'timestamp': timestamp, 'd': ['val_d', 'val2_d'], 'e': ['val_e', 'val2_e'], 'f': ['val_f', 'val2_f'],
     'g': ['val_g', 'val2_g']}, index=timestamp)
print(df2)
 

# keeping a value in common with the first index
timestamp = [1440540000, 1450560000]
df3 = pd.DataFrame({'timestamp': timestamp, 'h': ['val_h', 'val2_h'], 'i': ['val_i', 'val2_i']}, index=timestamp)
print(df3)

 
# Setting the timestamp as the index
df1.set_index('timestamp', inplace=True)
df2.set_index('timestamp', inplace=True)
df3.set_index('timestamp', inplace=True)
 
# You can convert timestamps to dates but it's not mandatory I think
df1.index = pd.to_datetime(df1.index, unit='s')
df2.index = pd.to_datetime(df2.index, unit='s')
df3.index = pd.to_datetime(df3.index, unit='s')
 
# Just perform a join and that's it
#result=df1.merge(df2, on='timestamp',how='left').merge(df3, on='timestamp',how='left')
result = df1.join(df2, how='outer').join(df3, how='outer')
result
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#       <th>e</th>
#       <th>f</th>
#       <th>g</th>
#       <th>h</th>
#       <th>i</th>
#     </tr>
#     <tr>
#       <th>timestamp</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2015-08-25 22:00:00.000000000</th>
#       <td>val_a</td>
#       <td>val_b</td>
#       <td>val_c</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>val_h</td>
#       <td>val_i</td>
#     </tr>
#     <tr>
#       <th>2015-12-19 15:46:40.000000000</th>
#       <td>val2_a</td>
#       <td>val2_b</td>
#       <td>val2_c</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2015-12-19 21:20:00.000000000</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>val2_h</td>
#       <td>val2_i</td>
#     </tr>
#     <tr>
#       <th>2029-06-25 19:42:46.056887627</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>val_d</td>
#       <td>val_e</td>
#       <td>val_f</td>
#       <td>val_g</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2029-11-23 15:19:32.399348736</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>val2_d</td>
#       <td>val2_e</td>
#       <td>val2_f</td>
#       <td>val2_g</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ax = plt.gca()

OutdoorTemp2019.plot(kind='line',x='Timestamp',y='RTU_1 OutdoorTemp(°F)',ax=ax)
RATemp2019.plot(kind='line',x='Timestamp',y='RTU_1 RATemp(°F)', color='red', ax=ax)
plt.xticks(rotation='vertical')

plt.show()
#here we're looking at retrun air vs outdoor temp
#anywhere where OutDoorTemp>RATemp we expect the 
#economizer to be active
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3684778184123180&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> ax <span class="ansi-blue-fg">=</span> plt<span class="ansi-blue-fg">.</span>gca<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span>
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg"> </span>OutdoorTemp2019<span class="ansi-blue-fg">.</span>plot<span class="ansi-blue-fg">(</span>kind<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;line&#39;</span><span class="ansi-blue-fg">,</span>x<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;Timestamp&#39;</span><span class="ansi-blue-fg">,</span>y<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;RTU_1 OutdoorTemp(°F)&#39;</span><span class="ansi-blue-fg">,</span>ax<span class="ansi-blue-fg">=</span>ax<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> RATemp2019<span class="ansi-blue-fg">.</span>plot<span class="ansi-blue-fg">(</span>kind<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;line&#39;</span><span class="ansi-blue-fg">,</span>x<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;Timestamp&#39;</span><span class="ansi-blue-fg">,</span>y<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;RTU_1 RATemp(°F)&#39;</span><span class="ansi-blue-fg">,</span> color<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;red&#39;</span><span class="ansi-blue-fg">,</span> ax<span class="ansi-blue-fg">=</span>ax<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span> plt<span class="ansi-blue-fg">.</span>xticks<span class="ansi-blue-fg">(</span>rotation<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;vertical&#39;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;OutdoorTemp2019&#39; is not defined</div>

# %%
df0.merge(df14, on='Timestamp',how='right')

# %%
print(all_csv_files)

# %%
dbfs ls

# %%
f

# %%
a="Testing"
